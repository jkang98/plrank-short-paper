# %%
import ast
import glob
import json
import re
from collections import OrderedDict

import matplotlib.pyplot as plt
import numpy as np

# %%
NN_files = glob.glob("experiment_nn_yahoo_50-*.out")

NN_NDCGs = []
NN_runtimes = []
for file in NN_files:
    with open(file, "r") as f:
        line = f.readlines()
    ndcg_value = []
    time = []
    for dic in eval(line[0]):
        ndcg_value.append(dic["test result"]["dataset normalized maximum likelihood"])
        time.append(dic["total time"])
    NN_runtimes.append(time)
    NN_NDCGs.append(ndcg_value)

# %%
NN_log_files = glob.glob("experiment_nn_log_yahoo_50-*.out")

NN_log_NDCGs = []
NN_log_runtimes = []
for file in NN_log_files:
    with open(file, "r") as f:
        line = f.readlines()
    ndcg_value = []
    time = []
    for dic in eval(line[0]):
        ndcg_value.append(dic["test result"]["dataset normalized maximum likelihood"])
        time.append(dic["total time"])
    NN_log_runtimes.append(time)
    NN_log_NDCGs.append(ndcg_value)

# %%
XGBoost_files = glob.glob("experiment_xgboost_yahoo_50-*.out")

XGBoost_NDCGs = []
XGBoost_runtimes = []
for file in XGBoost_files:
    with open(file, "r") as f:
        lines = f.readlines()
    time = []
    for i in eval(lines[1]):
        time.append(i["time"])
    XGBoost_runtimes.append(time)
    XGBoost_NDCGs.append(eval(lines[0])["test"]["NDCG@50"])

# %%
XGBoost_log_files = glob.glob("experiment_xgboost_log_yahoo_50-*.out")

XGBoost_log_NDCGs = []
XGBoost_log_runtimes = []
for file in XGBoost_log_files:
    with open(file, "r") as f:
        lines = f.readlines()
    time = []
    for i in eval(lines[1]):
        time.append(i["time"])
    XGBoost_log_runtimes.append(time)
    XGBoost_log_NDCGs.append(eval(lines[0])["test"]["NDCG@50"])

# %%
XGBoost_1000_samples_files = glob.glob("experiment_xgboost_yahoo_50(1000_samples)-*.out")

XGBoost_1000_samples_NDCGs = []
XGBoost_1000_samples_runtimes = []
for file in XGBoost_1000_samples_files:
    with open(file, "r") as f:
        lines = f.readlines()
    time = []
    for i in eval(lines[1]):
        time.append(i["time"])
    XGBoost_1000_samples_runtimes.append(time)
    XGBoost_1000_samples_NDCGs.append(eval(lines[0])["test"]["NDCG@50"])

# %%
Without_Hessian_files = glob.glob("experiment_without_hessian_yahoo_50-*.out")

Without_Hessian_NDCGs = []
Without_Hessian_runtimes = []
for file in Without_Hessian_files:
    with open(file, "r") as f:
        lines = f.readlines()
    time = []
    for i in eval(lines[1]):
        time.append(i["time"])
    Without_Hessian_runtimes.append(time)
    Without_Hessian_NDCGs.append(eval(lines[0])["test"]["NDCG@50"])

# %%
Without_Hessian_1000_samples_files = glob.glob("experiment_without_hessian_yahoo_50(1000_samples)-*.out")

Without_Hessian_1000_samples_NDCGs = []
Without_Hessian_1000_samples_runtimes = []
for file in Without_Hessian_1000_samples_files:
    with open(file, "r") as f:
        lines = f.readlines()
    time = []
    for i in eval(lines[1]):
        time.append(i["time"])
    Without_Hessian_1000_samples_runtimes.append(time)
    Without_Hessian_1000_samples_NDCGs.append(eval(lines[0])["test"]["NDCG@50"])

# %%
plt.figure(figsize=(20, 12))
plt.plot(
    np.mean(np.array(NN_runtimes), axis=0),
    np.mean(np.array(NN_NDCGs), axis=0),
    label="NN",
)
plt.plot(
    np.mean(np.array(NN_log_runtimes), axis=0),
    np.mean(np.array(NN_log_NDCGs), axis=0),
    label="NN_log",
)
plt.plot(
    np.mean(np.array(XGBoost_1000_samples_runtimes), axis=0),
    np.mean(np.array(XGBoost_1000_samples_NDCGs), axis=0),
    label="XGBoost_1000_samples",
)
plt.plot(
    np.mean(np.array(XGBoost_runtimes), axis=0),
    np.mean(np.array(XGBoost_NDCGs), axis=0),
    label="XGBoost",
)
plt.plot(
    np.mean(np.array(XGBoost_log_runtimes), axis=0),
    np.mean(np.array(XGBoost_log_NDCGs), axis=0),
    label="XGBoost_log",
)
plt.plot(
    np.mean(np.array(Without_Hessian_1000_samples_runtimes), axis=0),
    np.mean(np.array(Without_Hessian_1000_samples_NDCGs), axis=0),
    label="Without_Hessian_1000_samples",
)
plt.plot(
    np.mean(np.array(Without_Hessian_runtimes), axis=0),
    np.mean(np.array(Without_Hessian_NDCGs), axis=0),
    label="Without_Hessian",
)
plt.ylim(0.83, 0.87)
plt.legend()
plt.xlabel("seconds")
plt.ylabel("NDCG@50")
plt.show()

# %%
plt.figure(figsize=(20, 12))
plt.plot(
    np.arange(0, 501), np.mean(np.array(NN_NDCGs), axis=0), label="NN",
)
plt.plot(
    np.arange(0, 501), np.mean(np.array(NN_log_NDCGs), axis=0), label="NN_log",
)
plt.plot(
    np.arange(1, 701), np.mean(np.array(XGBoost_NDCGs), axis=0), label="XGBoost",
)
plt.plot(
    np.arange(1, 501), np.mean(np.array(XGBoost_log_NDCGs), axis=0), label="XGBoost_log",
)
plt.plot(
    np.arange(1, 501), np.mean(np.array(XGBoost_1000_samples_NDCGs), axis=0), label="XGBoost_1000_samples",
)
plt.plot(
    np.arange(1, 1001),
    np.mean(np.array(Without_Hessian_NDCGs), axis=0),
    label="Without_Hessian",
)
plt.plot(
    np.arange(1, 501),
    np.mean(np.array(Without_Hessian_1000_samples_NDCGs), axis=0),
    label="Without_Hessian_1000_samples",
)
plt.ylim(0.83, 0.87)
plt.legend()
plt.ylabel("NDCG@50")
plt.xlabel("epochs")
plt.show()
