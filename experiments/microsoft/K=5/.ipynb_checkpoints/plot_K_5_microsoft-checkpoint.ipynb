# %%
import ast
import glob
import json
import re
from collections import OrderedDict

import matplotlib.pyplot as plt
import numpy as np

# %%
NN_files = glob.glob("experiment_nn_5_fold_*-*.out")

NN_NDCGs = []
NN_runtimes = []
for file in NN_files:
    with open(file, "r") as f:
        line = f.readlines()
    ndcg_value = []
    time = []
    for dic in eval(line[0]):
        ndcg_value.append(dic["test result"]["dataset normalized maximum likelihood"])
        time.append(dic["total time"])
    NN_runtimes.append(time)
    NN_NDCGs.append(ndcg_value)

# %%
Without_Hessian_files = glob.glob("experiment_without_hessian_5_fold_*-*.out")

Without_Hessian_NDCGs = []
Without_Hessian_runtimes = []
for file in Without_Hessian_files:
    with open(file, "r") as f:
        lines = f.readlines()
    time = []
    for i in eval(lines[1]):
        time.append(i["time"])
    Without_Hessian_runtimes.append(time)
    Without_Hessian_NDCGs.append(eval(lines[0])["test"]["NDCG@5"])

# %%
XGBoost_shared_files = glob.glob("experiment_xgboost_shared_5_fold_*-*.out")

XGBoost_shared_NDCGs = []
XGBoost_shared_runtimes = []
for file in XGBoost_shared_files:
    with open(file, "r") as f:
        lines = f.readlines()
    time = []
    for i in eval(lines[1])[:1000]:
        time.append(i["time"])
    XGBoost_shared_runtimes.append(time)
    XGBoost_shared_NDCGs.append(eval(lines[0])["test"]["NDCG@5"][:1000])

# %%
lambdamart_files = glob.glob("experiment_lambdamart_5_fold_*-*.out")

lambdamart_NDCGs = []
lambdamart_runtimes = []
for file in lambdamart_files:
    with open(file, "r") as f:
        lines = f.readlines()
    time = []
    for i in eval(lines[1]):
        time.append(i["time"])
    lambdamart_runtimes.append(time)
    lambdamart_NDCGs.append(eval(lines[0])["test"]["NDCG@5"])

# %%
plt.figure(figsize=(20, 12))
plt.plot(
    np.arange(0, 1001), np.mean(np.array(NN_NDCGs), axis=0), label="NN",
)
plt.plot(
    np.arange(1, 1001),
    np.mean(np.array(XGBoost_shared_NDCGs), axis=0),
    label="XGBoost_shared",
)
# plt.axhline(
#     np.max(np.mean(np.array(lambdamart_NDCGs), axis=0)),
#     label="LambdaMART",
#     linestyle="dashed",
# )
# plt.plot(
#     np.arange(1, 1001), np.mean(np.array(XGBoost_NDCGs), axis=0), label="XGBoost",
# )
plt.plot(
    np.arange(1, 1001), np.mean(np.array(lambdamart_NDCGs), axis=0), label="LambdaMART",
)
plt.plot(
    np.arange(1, 1001),
    np.mean(np.array(Without_Hessian_NDCGs), axis=0),
    label="Without_Hessian",
)
plt.ylim(0.39, 0.496)
plt.xlim(0, 1000)
plt.legend()
plt.xlabel("epochs")
plt.ylabel("NDCG@5")
plt.show()

# %%
# Created by Harrie Oosterhuis,
# if you use this for your publication and I'm not a co-author,
# please thank me in the acknowledgements.

import matplotlib.lines as mlines
import pylab as plt

# latex font in matplotlib
plt.rc("font", size=20)
#plt.rc("text", usetex=True)
#plt.rc("text.latex", preamble=r"\usepackage{amsmath,amssymb,bm,bbm,lmodern}")

# parameters for plotting
name_mapping = {
    "method_1": "Neural Network",
    "method_2": "GBDT with Hessian",
    "method_3": "GBDT without Hessian",
}
colours = {
    "method_1": "violet",
    "method_2": "red",
    "method_3": "orange",
}
markers = {
    "method_1": "^",
    "method_2": "o",
    "method_3": "v",
}
styles = {
    "method_1": "-",
    "method_2": "-",
    "method_3": "-",
}

legend_info = []
fig = plt.figure(figsize=(6.1, 4.1), linewidth=0.5)
plt.ioff()
# plt.ylabel("Y-Axis Label")
# plt.xlabel("X-Axis Label")
# plt.xscale('log')
# plt.yscale('log')
plt.gca().yaxis.set_ticks_position("both")
plt.xlim(0, 1000)
#plt.xticks([0,100,200,300,400,500,600,700,800,900,1000])
plt.ylim(0.416, 0.486)
# plt.yticks([0,0.25,0.5,0.75,1])

data = {
    "method_1": (np.arange(0, 1001), np.mean(np.array(NN_NDCGs), axis=0)),
    "method_2": (np.arange(1, 1001), np.mean(np.array(XGBoost_shared_NDCGs), axis=0)),
    "method_3": (np.arange(1, 1001), np.mean(np.array(Without_Hessian_NDCGs), axis=0)),
}

for k in ["method_1", "method_2", "method_3"]:
    x, y = data[k]
    legend_info.append(
        {
            "linestyle": styles[k],
            "color": colours[k],
            "marker": markers[k],
            "markersize": 12,
            "markevery": 200,  # this should be higher if you have more data
            "fillstyle": "none",
            "label": name_mapping[k],
            "linewidth": 2.0,
        }
    )

    # for confidence bounds
    # plt.fill_between(x, y_min, y_max)
    #                 alpha=0.2,
    #                 color=legend_info[-1]['color'])
    plt.plot(x, y, **legend_info[-1])

# plt.title('Nice Title')
# in case you do want the legend in the figure
# plt.legend(ncol=2)

plt.savefig("microsoft_5.pdf", bbox_inches="tight", pad_inches=0)
plt.close()

# in case you want to change the order in the legend but not in the plot
# legend_info = [legend_info[i] for i in [2,0,1]]

figlegend = plt.figure(figsize=(0.5, 0.5))

ncol = 3
figlegend.legend(
    handles=[mlines.Line2D([], [], **l) for l in legend_info],
    fontsize=18,
    loc="center",
    ncol=ncol,
    frameon=False,
    borderaxespad=0,
    borderpad=0,
    labelspacing=0.2,
    columnspacing=1.0,
)
figlegend.savefig(
    "legend.pdf", bbox_inches="tight"
)  # , pad_inches=0)
plt.close()

# %%
np.round(np.max(np.array(NN_NDCGs),axis=1),4)
# Out:
# array([0.4828, 0.4834, 0.4839, 0.4839, 0.4838, 0.48  , 0.4777, 0.4806,
#        0.4794, 0.481 , 0.4793, 0.4793, 0.4824, 0.4799, 0.4782, 0.4792,
#        0.4793, 0.4781, 0.4775, 0.4774, 0.4826, 0.4826, 0.4841, 0.4835,
#        0.4842])

# %%
np.round(np.mean(np.max(np.array(NN_NDCGs),axis=1)),4)
# Out:
# 0.481

# %%
np.round(np.std(np.max(np.array(NN_NDCGs),axis=1)),4)
# Out:
# 0.0023

# %%
np.round(np.max(np.array(XGBoost_shared_NDCGs),axis=1),4)
# Out:
# array([0.4734, 0.4708, 0.4893, 0.4921, 0.4808, 0.4743, 0.4716, 0.4739,
#        0.4903, 0.4875, 0.4867, 0.4911, 0.4909, 0.4869, 0.4905, 0.4918,
#        0.4881, 0.4882, 0.4775, 0.4813, 0.4913, 0.478 , 0.4913, 0.4922,
#        0.4804])

# %%
np.round(np.mean(np.max(np.array(XGBoost_shared_NDCGs),axis=1)),4)
# Out:
# 0.4844

# %%
np.round(np.std(np.max(np.array(XGBoost_shared_NDCGs),axis=1)),4)
# Out:
# 0.0072

# %%
np.round(np.max(np.array(Without_Hessian_NDCGs),axis=1),4)
# Out:
# array([0.4283, 0.4289, 0.4283, 0.431 , 0.4298, 0.4286, 0.4321, 0.4284,
#        0.4272, 0.4284, 0.427 , 0.436 , 0.4351, 0.4347, 0.4357, 0.4347,
#        0.4344, 0.4344, 0.435 , 0.4264, 0.4346, 0.4346, 0.427 , 0.4302,
#        0.4307])

# %%
np.round(np.mean(np.max(np.array(Without_Hessian_NDCGs),axis=1)),4)
# Out:
# 0.4313

# %%
np.round(np.std(np.max(np.array(Without_Hessian_NDCGs),axis=1)),4)
# Out:
# 0.0032

# %%
np.round(np.max(np.array(lambdamart_NDCGs), axis=1),4)
# Out:
# array([0.4894, 0.4868, 0.4908, 0.4879, 0.4896])

# %%
np.round(np.mean(np.max(np.array(lambdamart_NDCGs),axis=1)),4)
# Out:
# 0.4889

# %%
np.round(np.std(np.max(np.array(lambdamart_NDCGs),axis=1)),4)
# Out:
# 0.0014

# %%
XGBoost_in_files = glob.glob("experiment_xgboost_shared_5_fold_1-*.out")

XGBoost_in_NDCGs = []
XGBoost_in_runtimes = []
for file in XGBoost_in_files:
    with open(file, "r") as f:
        lines = f.readlines()
    time = []
    for i in eval(lines[1])[:1000]:
        time.append(i["time"])
    XGBoost_in_runtimes.append(time)
    XGBoost_in_NDCGs.append(eval(lines[0])["test"]["NDCG@5"][:1000])

# %%
XGBoost_out_files = glob.glob("useless results/experiment_xgboost_shared_5_fold_1-*.out")

XGBoost_out_NDCGs = []
XGBoost_out_runtimes = []
for file in XGBoost_out_files:
    with open(file, "r") as f:
        lines = f.readlines()
    time = []
    for i in eval(lines[1])[:1000]:
        time.append(i["time"])
    XGBoost_out_runtimes.append(time)
    XGBoost_out_NDCGs.append(eval(lines[0])["test"]["NDCG@5"][:1000])

# %%
plt.figure(figsize=(20, 12))

plt.plot(
    np.arange(1, 1001),
    np.mean(np.array(XGBoost_in_NDCGs), axis=0),
    label="XGBoost_in",
)
plt.plot(
    np.arange(1, 1001),
    np.mean(np.array(XGBoost_out_NDCGs), axis=0),
    label="XGBoost_out",
)

plt.ylim(0.39, 0.496)
plt.xlim(0, 1000)
plt.legend()
plt.xlabel("epochs")
plt.ylabel("NDCG@5")
plt.show()
